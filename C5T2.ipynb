# %%
DatasetName <- read.csv("default of credit card clients.csv file")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b99d5d969e44> in <module>()
# ----> 1 DatasetName <- read.csv("default of credit card clients.csv file")
#
# NameError: name 'DatasetName' is not defined

# %%
Creditdefault <- read.csv("default of credit card clients.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-be48fe95c71f> in <module>()
# ----> 1 Creditdefault <- read.csv("default of credit card clients.csv")
#
# NameError: name 'Creditdefault' is not defined

# %%
Creditdefault <- read.csv("default of credit card clients.csv", header =TRUE, sep=",")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-4b242a9362e1> in <module>()
# ----> 1 Creditdefault <- read.csv("default of credit card clients.csv", header =TRUE, sep=",")
#
# NameError: name 'Creditdefault' is not defined

# %%
import pandas as pd

# %%
credit = pd.read_csv('default.csv', header =1)

# %%
credit.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
#
#               ...              BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  \
# 0             ...                      0          0          0         0
# 1             ...                   3272       3455       3261         0
# 2             ...                  14331      14948      15549      1518
# 3             ...                  28314      28959      29547      2000
# 4             ...                  20940      19146      19131      2000
#
#    PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  \
# ...

# %%
credit.describe()
# Out:
#                  ID       LIMIT_BAL           SEX     EDUCATION      MARRIAGE  \
# count  30000.000000    30000.000000  30000.000000  30000.000000  30000.000000
# mean   15000.500000   167484.322667      1.603733      1.853133      1.551867
# std     8660.398374   129747.661567      0.489129      0.790349      0.521970
# min        1.000000    10000.000000      1.000000      0.000000      0.000000
# 25%     7500.750000    50000.000000      1.000000      1.000000      1.000000
# 50%    15000.500000   140000.000000      2.000000      2.000000      2.000000
# 75%    22500.250000   240000.000000      2.000000      2.000000      2.000000
# max    30000.000000  1000000.000000      2.000000      6.000000      3.000000
#
#                 AGE         PAY_0         PAY_2         PAY_3         PAY_4  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      35.485500     -0.016700     -0.133767     -0.166200     -0.220667
# ...

# %%
default.dtypes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-2350998bfdbb> in <module>()
# ----> 1 default.dtypes
#
# NameError: name 'default' is not defined

# %%
>>> default. dtypes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-0dcf54ca157b> in <module>()
# ----> 1 default. dtypes
#
# NameError: name 'default' is not defined

# %%
>>> df . dtypes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-b2e64cdd90bc> in <module>()
# ----> 1 df . dtypes
#
# NameError: name 'df' is not defined

# %%
>>> credit. dtypes
# Out:
# ID                            int64
# LIMIT_BAL                     int64
# SEX                           int64
# EDUCATION                     int64
# MARRIAGE                      int64
# AGE                           int64
# PAY_0                         int64
# PAY_2                         int64
# PAY_3                         int64
# PAY_4                         int64
# PAY_5                         int64
# PAY_6                         int64
# BILL_AMT1                     int64
# BILL_AMT2                     int64
# BILL_AMT3                     int64
# BILL_AMT4                     int64
# BILL_AMT5                     int64
# BILL_AMT6                     int64
# PAY_AMT1                      int64
# PAY_AMT2                      int64
# PAY_AMT3                      int64
# PAY_AMT4                      int64
# PAY_AMT5                      int64
# PAY_AMT6                      int64
# default payment next month    int64
# dtype: object

# %%
# Delete a column

# %%
>>>del credit [’ID ’]
# Out:
#   File "<ipython-input-13-c8306387ea64>", line 1
#     >>>del credit [’ID ’]
#      ^
# SyntaxError: invalid syntax

# %%
>>>del credit [’ID’]
# Out:
#   File "<ipython-input-14-67169e2bd5cc>", line 1
#     >>>del credit [’ID’]
#      ^
# SyntaxError: invalid syntax

# %%
del df['ID']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-669c4c3706a0> in <module>()
# ----> 1 del df['ID']
#
# NameError: name 'df' is not defined

# %%
del credit['ID']

# %%
credit.isnull().values.any()
# Out:
# False

# %%
credit = pd.DataFrame({"SEX":[1,2], "SEX":['male', 'female',]})

# %%
>>> credit. dtypes
# Out:
# SEX    object
# dtype: object

# %%
credit.head(5)
# Out:
#       SEX
# 0    male
# 1  female

# %%
credit = pd.read_csv('default.csv', header =1)

# %%
credit.head(5)
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
#
#               ...              BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  \
# 0             ...                      0          0          0         0
# 1             ...                   3272       3455       3261         0
# 2             ...                  14331      14948      15549      1518
# 3             ...                  28314      28959      29547      2000
# 4             ...                  20940      19146      19131      2000
#
#    PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  \
# ...

# %%
credit['SEX'] = df.zipcode.astype('category')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-95e18e43fc52> in <module>()
# ----> 1 credit['SEX'] = df.zipcode.astype('category')
#
# NameError: name 'df' is not defined

# %%
df['SEX'] = credit.sex.astype('category')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-2f0536c7ce47> in <module>()
# ----> 1 df['SEX'] = credit.sex.astype('category')
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4370             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4371                 return self[name]
# -> 4372             return object.__getattribute__(self, name)
#    4373
#    4374     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'sex'

# %%
credit['SEX'] = credit.SEX.astype('category')

# %%
credit['EDUCATION'] = credit.EDUCATION.astype('category')

# %%
credit['MARRIAGE'] = credit.MARRIAGE.astype('category')

# %%
data.SEX[data.SEX == '1'] = male
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-2ea547236541> in <module>()
# ----> 1 data.SEX[data.SEX == '1'] = male
#
# NameError: name 'male' is not defined

# %%
credit.SEX[credit.SEX == '1'] = male
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-acfdd55687b1> in <module>()
# ----> 1 credit.SEX[credit.SEX == '1'] = male
#
# NameError: name 'male' is not defined

# %%
credit.SEX[credit.SEX == '1'] = 'male'
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-a4713553b87a> in <module>()
# ----> 1 credit.SEX[credit.SEX == '1'] = 'male'
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in __setitem__(self, key, value)
#     936         # do the setitem
#     937         cacher_needs_updating = self._check_is_chained_assignment_possible()
# --> 938         setitem(key, value)
#     939         if cacher_needs_updating:
#     940             self._maybe_update_cacher()
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in setitem(key, value)
#     927                 key = check_bool_indexer(self.index, key)
#     928                 try:
# --> 929                     self._where(~key, value, inplace=True)
#     930                     return
#     931                 except InvalidIndexError:
#
# ...

# %%
credit.SEX[credit.SEX == 1] = 'male'
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-1211f77f38ce> in <module>()
# ----> 1 credit.SEX[credit.SEX == 1] = 'male'
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in __setitem__(self, key, value)
#     936         # do the setitem
#     937         cacher_needs_updating = self._check_is_chained_assignment_possible()
# --> 938         setitem(key, value)
#     939         if cacher_needs_updating:
#     940             self._maybe_update_cacher()
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in setitem(key, value)
#     927                 key = check_bool_indexer(self.index, key)
#     928                 try:
# --> 929                     self._where(~key, value, inplace=True)
#     930                     return
#     931                 except InvalidIndexError:
#
# ...

# %%
import matplotlib.pyplot as plt

# %%
header = credit.dtypes.index

# %%
print(header)
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month'],
#       dtype='object')

# %%
plt.hist(credit['LIMIT_BAL'])
plt.show()

# %%
plt.hist(credit['LIMIT_BAL'], bins=4)
# Out:
# (array([2.3283e+04, 6.5110e+03, 2.0000e+02, 6.0000e+00]),
#  array([  10000.,  257500.,  505000.,  752500., 1000000.]),
#  <a list of 4 Patch objects>)

# %%
plt.plot(credit['LIMIT_BAL'])
plt.show()

# %%
x = credit['PAY_0']
y = credit['PAY_2']

# %%
plt.scatter(x,y)
plt.show()

# %%
header = credit.dtypes.index
print(header)
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month'],
#       dtype='object')

# %%
A = credit['BILL_AMT1']
plt.boxplot(A,0,'gD')
plt.show()

# %%
corrMat = credit.corr()
print(corrMat)
# Out:
#                                   ID  LIMIT_BAL       AGE     PAY_0     PAY_2  \
# ID                          1.000000   0.026179  0.018678 -0.030575 -0.011215
# LIMIT_BAL                   0.026179   1.000000  0.144713 -0.271214 -0.296382
# AGE                         0.018678   0.144713  1.000000 -0.039447 -0.050148
# PAY_0                      -0.030575  -0.271214 -0.039447  1.000000  0.672164
# PAY_2                      -0.011215  -0.296382 -0.050148  0.672164  1.000000
# PAY_3                      -0.018494  -0.286123 -0.053048  0.574245  0.766552
# PAY_4                      -0.002735  -0.267460 -0.049722  0.538841  0.662067
# PAY_5                      -0.022199  -0.249411 -0.053826  0.509426  0.622780
# PAY_6                      -0.020270  -0.235195 -0.048773  0.474553  0.575501
# BILL_AMT1                   0.019389   0.285430  0.056239  0.187068  0.234887
# BILL_AMT2                   0.017982   0.278314  0.054283  0.189859  0.235257
# ...

# %%
covMat = credit.cov()
print(covMat)
# Out:
#                                       ID     LIMIT_BAL            AGE  \
# ID                          7.500250e+07  2.941664e+07    1491.057019
# LIMIT_BAL                   2.941664e+07  1.683446e+10  173076.722569
# AGE                         1.491057e+03  1.730767e+05      84.969755
# PAY_0                      -2.975726e+02 -3.954593e+04      -0.408639
# PAY_2                      -1.162770e+02 -4.603765e+04      -0.553408
# PAY_3                      -1.916922e+02 -4.443225e+04      -0.585263
# PAY_4                      -2.769132e+01 -4.057181e+04      -0.535851
# PAY_5                      -2.178600e+02 -3.667056e+04      -0.562245
# PAY_6                      -2.018774e+02 -3.509308e+04      -0.517022
# BILL_AMT1                   1.236447e+07  2.727020e+09   38172.933546
# BILL_AMT2                   1.108392e+07  2.570130e+09   35613.657962
# BILL_AMT3                   1.462688e+07  2.548533e+09   34334.251320
# ...

# %%
>>> credit.remove_feature('ID')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-44-5014d134218c> in <module>()
# ----> 1 credit.remove_feature('ID')
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4370             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4371                 return self[name]
# -> 4372             return object.__getattribute__(self, name)
#    4373
#    4374     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'remove_feature'

# %%
coorMat

# %%
corrMat.style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_4c15223a_e07f_11e8_997a_c86000a18ederow0_col0 {
#             background-color:  #023858;
#         }    #T_4c15223a_e07f_11e8_997a_c86000a18ederow0_col1 {
#             background-color:  #d1d2e6;
#         }    #T_4c15223a_e07f_11e8_997a_c86000a18ederow0_col2 {
#             background-color:  #f5eef6;
#         }    #T_4c15223a_e07f_11e8_997a_c86000a18ederow0_col3 {
#             background-color:  #dedcec;
#         }    #T_4c15223a_e07f_11e8_997a_c86000a18ederow0_col4 {
#             background-color:  #d7d6e9;
#         }    #T_4c15223a_e07f_11e8_997a_c86000a18ederow0_col5 {
#             background-color:  #d9d8ea;
#         }    #T_4c15223a_e07f_11e8_997a_c86000a18ederow0_col6 {
#             background-color:  #d9d8ea;
#         }    #T_4c15223a_e07f_11e8_997a_c86000a18ederow0_col7 {
#             background-color:  #e0dded;
#         }    #T_4c15223a_e07f_11e8_997a_c86000a18ederow0_col8 {
#             background-color:  #e1dfed;
# ...

# %%
pd.scatter_matrix(credt, alpha = 0.3, figsize = (14,8), diagonal = 'kde');
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-885d967bc7b7> in <module>()
# ----> 1 pd.scatter_matrix(credt, alpha = 0.3, figsize = (14,8), diagonal = 'kde');
#
# NameError: name 'credt' is not defined

# %%
sns.heatmap(corrMat, mask=np.zeros_like(corr, dtype=np.bool), cmap=sns.diverging_palette(220, 10, as_cmap=True),
            square=True, ax=ax)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-22bbe8633ccd> in <module>()
# ----> 1 sns.heatmap(corrMat, mask=np.zeros_like(corr, dtype=np.bool), cmap=sns.diverging_palette(220, 10, as_cmap=True),
#       2             square=True, ax=ax)
#
# NameError: name 'sns' is not defined

# %%
CorrMat['default payment next month'].sort_values(ascending=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-21b8babfe780> in <module>()
# ----> 1 CorrMat['default payment next month'].sort_values(ascending=False)
#
# NameError: name 'CorrMat' is not defined

# %%
core = df.corrMat()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-55581ad24246> in <module>()
# ----> 1 core = df.corrMat()
#
# NameError: name 'df' is not defined

# %%
core = credit.corr()

# %%
c1 = corr.abs().unstack()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-4c4cd649ba88> in <module>()
# ----> 1 c1 = corr.abs().unstack()
#
# NameError: name 'corr' is not defined

# %%
core.sort_values(ascending = True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-53-65ef73b88876> in <module>()
# ----> 1 core.sort_values(ascending = True)
#
# TypeError: sort_values() missing 1 required positional argument: 'by'

# %%
credit.corr().unstack().sort_values().drop_duplicates()
# Out:
# LIMIT_BAL                   PAY_2                        -0.296382
# PAY_3                       LIMIT_BAL                    -0.286123
# LIMIT_BAL                   PAY_0                        -0.271214
#                             PAY_4                        -0.267460
# PAY_5                       LIMIT_BAL                    -0.249411
# PAY_6                       LIMIT_BAL                    -0.235195
# LIMIT_BAL                   default payment next month   -0.153520
# PAY_AMT1                    PAY_2                        -0.080701
# PAY_0                       PAY_AMT1                     -0.079269
# default payment next month  PAY_AMT1                     -0.072929
# PAY_AMT3                    PAY_0                        -0.070561
# PAY_AMT2                    PAY_0                        -0.070101
# PAY_AMT3                    PAY_4                        -0.069235
# PAY_3                       PAY_AMT2                     -0.066793
# ...

# %%
credit.cov().unstack().sort_values().drop_duplicates()
# Out:
# PAY_2      LIMIT_BAL                    -4.603765e+04
# LIMIT_BAL  PAY_3                        -4.443225e+04
# PAY_4      LIMIT_BAL                    -4.057181e+04
# LIMIT_BAL  PAY_0                        -3.954593e+04
#            PAY_5                        -3.667056e+04
#            PAY_6                        -3.509308e+04
#            default payment next month   -8.267552e+03
# PAY_AMT2   PAY_3                        -1.841953e+03
# PAY_0      PAY_AMT2                     -1.815138e+03
# PAY_AMT2   PAY_2                        -1.627192e+03
# PAY_AMT1   PAY_2                        -1.600241e+03
# PAY_0      PAY_AMT1                     -1.475495e+03
# PAY_AMT3   PAY_4                        -1.425205e+03
# PAY_0      PAY_AMT3                     -1.396168e+03
# PAY_2      PAY_AMT3                     -1.178331e+03
# PAY_0      PAY_AMT6                     -1.172194e+03
# PAY_AMT4   PAY_0                        -1.126848e+03
# ...

# %%
import matplotlib.pyplot as plt
pd.options.display.mpl_style = 'default'
credit.boxplot()
# Out:
# ---------------------------------------------------------------------------
# OptionError                               Traceback (most recent call last)
# <ipython-input-56-be2678004933> in <module>()
#       1 import matplotlib.pyplot as plt
# ----> 2 pd.options.display.mpl_style = 'default'
#       3 credit.boxplot()
#
# ~\Anaconda3\lib\site-packages\pandas\core\config.py in __setattr__(self, key, val)
#     190             _set_option(prefix, val)
#     191         else:
# --> 192             raise OptionError("You can only set the value of existing options")
#     193
#     194     def __getattr__(self, key):
#
# OptionError: 'You can only set the value of existing options'

# %%
import matplotlib.pyplot as plt

# %%
pd.options.display.mpl_style = 'default'
# Out:
# ---------------------------------------------------------------------------
# OptionError                               Traceback (most recent call last)
# <ipython-input-58-959c6ca8b728> in <module>()
# ----> 1 pd.options.display.mpl_style = 'default'
#
# ~\Anaconda3\lib\site-packages\pandas\core\config.py in __setattr__(self, key, val)
#     190             _set_option(prefix, val)
#     191         else:
# --> 192             raise OptionError("You can only set the value of existing options")
#     193
#     194     def __getattr__(self, key):
#
# OptionError: 'You can only set the value of existing options'

# %%
credit.boxplot()

# %%
credit.groupby('age').hist()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-60-85605ca85c40> in <module>()
# ----> 1 credit.groupby('age').hist()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, **kwargs)
#    6657         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    6658                        sort=sort, group_keys=group_keys, squeeze=squeeze,
# -> 6659                        observed=observed, **kwargs)
#    6660
#    6661     def asfreq(self, freq, method=None, how=None, normalize=False,
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in groupby(obj, by, **kwds)
#    2150         raise TypeError('invalid type: %s' % type(obj))
#    2151
# -> 2152     return klass(obj, by, **kwds)
#    2153
#    2154
#
# ...

# %%
credit.groupby('AGE').hist()
# Out:
# C:\Users\Jacob\Anaconda3\lib\site-packages\matplotlib\pyplot.py:537: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# AGE
# 21    [[AxesSubplot(0.125,0.758226;0.125x0.121774), ...
# 22    [[AxesSubplot(0.125,0.758226;0.125x0.121774), ...
# 23    [[AxesSubplot(0.125,0.758226;0.125x0.121774), ...
# 24    [[AxesSubplot(0.125,0.758226;0.125x0.121774), ...
# 25    [[AxesSubplot(0.125,0.758226;0.125x0.121774), ...
# 26    [[AxesSubplot(0.125,0.758226;0.125x0.121774), ...
# 27    [[AxesSubplot(0.125,0.758226;0.125x0.121774), ...
# 28    [[AxesSubplot(0.125,0.758226;0.125x0.121774), ...
# 29    [[AxesSubplot(0.125,0.758226;0.125x0.121774), ...
# 30    [[AxesSubplot(0.125,0.758226;0.125x0.121774), ...
# ...

# %%
covMat.style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_356dd974_e08f_11e8_90b3_c86000a18ederow0_col0 {
#             background-color:  #023858;
#         }    #T_356dd974_e08f_11e8_90b3_c86000a18ederow0_col1 {
#             background-color:  #fff7fb;
#         }    #T_356dd974_e08f_11e8_90b3_c86000a18ederow0_col2 {
#             background-color:  #fef6fa;
#         }    #T_356dd974_e08f_11e8_90b3_c86000a18ederow0_col3 {
#             background-color:  #1379b5;
#         }    #T_356dd974_e08f_11e8_90b3_c86000a18ederow0_col4 {
#             background-color:  #1c7fb8;
#         }    #T_356dd974_e08f_11e8_90b3_c86000a18ederow0_col5 {
#             background-color:  #1e80b8;
#         }    #T_356dd974_e08f_11e8_90b3_c86000a18ederow0_col6 {
#             background-color:  #2484ba;
#         }    #T_356dd974_e08f_11e8_90b3_c86000a18ederow0_col7 {
#             background-color:  #2d8abd;
#         }    #T_356dd974_e08f_11e8_90b3_c86000a18ederow0_col8 {
#             background-color:  #348ebf;
# ...

# %%
credit.groupby('SEX')['SEX'].count()
# Out:
# SEX
# 1    11888
# 2    18112
# Name: SEX, dtype: int64

# %%
sns.factorplot('SEX', data=credit, kind='count', aspect=1.5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-64-83e110a79b1b> in <module>()
# ----> 1 sns.factorplot('SEX', data=credit, kind='count', aspect=1.5)
#
# NameError: name 'sns' is not defined

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.factorplot('SEX', data=credit, kind='count', aspect=1.5)

# %%
titanic_df.groupby(['SEX', 'default payment next month'])['SEX'].count()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-67-9161c84cf8f6> in <module>()
# ----> 1 titanic_df.groupby(['SEX', 'default payment next month'])['SEX'].count()
#
# NameError: name 'titanic_df' is not defined

# %%
credit.groupby(['SEX', 'default payment next month'])['SEX'].count()
# Out:
# SEX  default payment next month
# 1    0                              9015
#      1                              2873
# 2    0                             14349
#      1                              3763
# Name: SEX, dtype: int64

# %%
g = sns.factorplot('default payment next month', data=credit, hue='SEX', kind='count', aspect=1.75)

# %%
plt.hist(credit['PAY_0'])
plt.show()

# %%
credit.groupby(['PAY_0', 'default payment next month'])['PAY_0'].count()
# Out:
# PAY_0  default payment next month
# -2     0                              2394
#        1                               365
# -1     0                              4732
#        1                               954
#  0     0                             12849
#        1                              1888
#  1     0                              2436
#        1                              1252
#  2     0                               823
#        1                              1844
#  3     0                                78
#        1                               244
#  4     0                                24
#        1                                52
#  5     0                                13
#        1                                13
#  6     0                                 5
#        1                                 6
#  7     0                                 2
#        1                                 7
#  8     0                                 8
# ...

# %%
g = sns.factorplot('default payment next month', data=credit, hue='PAY_0', kind='count', aspect=1.75)

# %%
age_dist = sns.distplot(AGE)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-73-b1bc7b322382> in <module>()
# ----> 1 age_dist = sns.distplot(AGE)
#
# NameError: name 'AGE' is not defined

# %%
age = credit['AGE']

# %%
age_dist = sns.distplot(AGE)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-75-b1bc7b322382> in <module>()
# ----> 1 age_dist = sns.distplot(AGE)
#
# NameError: name 'AGE' is not defined

# %%
age_dist = sns.distplot('AGE')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-76-a08ef01ff23e> in <module>()
# ----> 1 age_dist = sns.distplot('AGE')
#
# ~\Anaconda3\lib\site-packages\seaborn\distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     193             line, = ax.plot(0, a.mean())
#     194         else:
# --> 195             line, = ax.plot(a.mean(), 0)
#     196         color = line.get_color()
#     197         line.remove()
#
# ~\Anaconda3\lib\site-packages\numpy\core\_methods.py in _mean(a, axis, dtype, out, keepdims)
#      68             is_float16_result = True
#      69
# ---> 70     ret = umr_sum(arr, axis, dtype, out, keepdims)
#      71     if isinstance(ret, mu.ndarray):
#      72         ret = um.true_divide(
#
# TypeError: cannot perform reduce with flexible type

# %%
age_dist = sns.distplot(age)
# Out:
# C:\Users\Jacob\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
fig = sns.FacetGrid(credit, hue='SEX', aspect=4)
fig.map(sns.kdeplot, 'AGE', shade=True)
oldest = titanic_df['AGE'].max()
fig.set(xlim=(0,oldest))
fig.set(title='Distribution of Age Grouped by Gender')
fig.add_legend()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-78-ecfd9b52570e> in <module>()
#       1 fig = sns.FacetGrid(credit, hue='SEX', aspect=4)
#       2 fig.map(sns.kdeplot, 'AGE', shade=True)
# ----> 3 oldest = titanic_df['AGE'].max()
#       4 fig.set(xlim=(0,oldest))
#       5 fig.set(title='Distribution of Age Grouped by Gender')
#
# NameError: name 'titanic_df' is not defined

# %%
fig = sns.FacetGrid(credit, hue='SEX', aspect=4)
fig.map(sns.kdeplot, 'AGE', shade=True)
oldest = credit['AGE'].max()
fig.set(xlim=(0,oldest))
fig.set(title='Distribution of Age Grouped by Gender')
fig.add_legend()

# %%
fig = sns.FacetGrid(credit, hue='default payment next month', aspect=4)
fig.map(sns.kdeplot, 'AGE', shade=True)
oldest = credit['AGE'].max()
fig.set(xlim=(0,oldest))
fig.set(title='Distribution of Age Grouped by Gender')
fig.add_legend()

# %%
f = sns.factorplot('default payment next month', data=credit, hue='AGE', kind='count', aspect=1.75)
